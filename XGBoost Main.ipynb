# %%
import Remake_Dataset as rd 
import XGBoostModel as xgbm
import ModelPerformace as mp
import pandas as pd

# %%
Dataset = rd.Remake()

# %%
New_Data = pd.DataFrame({
    "Light Conditions": ["Daylight"],
    "Number of Casualties": [11],
    "Number of Vehicles": [5],
    "Road Surface Conditions": ["Wet or damp"],
    "Road Type": ["Dual carriageway"],
    "Speed limit": [30],
    "Urban or Rural Area": ["Urban"],
    "Weather Conditions": ["Raining no high winds"]
})

Model = xgbm.XGboost_Model(Dataset, New_Data)
# Out:
# Model not found!! Training the model now...

# %%
print(mp.Confusion_Matrix_Train(Model.Results_Performance))
# Out:
# Accuracy for Train set: 84.7583105182305%
# None

# %%
print(mp.Confusion_Matrix_Test(Model.Results_Performance))
# Out:
# Accuracy for Test set: 84.69930541308871
# None
